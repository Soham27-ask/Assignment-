# %% [markdown]
# Question 1: What is Simple Linear Regression?

# %%
print('Simple Linear Regression is a statistical method that models the relationship between a dependent variable and one independent variable using a straight line.')
# Out:
# Simple Linear Regression is a statistical method that models the relationship between a dependent variable and one independent variable using a straight line.

# %% [markdown]
# Question 2: What are the key assumptions of Simple Linear Regression?

# %%
print('Key assumptions: Linearity, Independence of errors, Homoscedasticity, Normality of residuals, No multicollinearity.')
# Out:
# Key assumptions: Linearity, Independence of errors, Homoscedasticity, Normality of residuals, No multicollinearity.

# %% [markdown]
# Question 3: What is heteroscedasticity, and why is it important to address in regression models?

# %%
print('Heteroscedasticity means unequal variance of residuals across levels of an independent variable. It can lead to inefficient estimates and biased hypothesis testing.')
# Out:
# Heteroscedasticity means unequal variance of residuals across levels of an independent variable. It can lead to inefficient estimates and biased hypothesis testing.

# %% [markdown]
# Question 4: What is Multiple Linear Regression?

# %%
print('Multiple Linear Regression models the relationship between one dependent variable and two or more independent variables.')
# Out:
# Multiple Linear Regression models the relationship between one dependent variable and two or more independent variables.

# %% [markdown]
# Question 5: What is polynomial regression, and how does it differ from linear regression?

# %%
print('Polynomial regression is a type of regression where the relationship between independent and dependent variables is modeled as an nth-degree polynomial. It differs from linear regression as it captures nonlinear trends.')
# Out:
# Polynomial regression is a type of regression where the relationship between independent and dependent variables is modeled as an nth-degree polynomial. It differs from linear regression as it captures nonlinear trends.

# %% [markdown]
# Question 6: Implement a Python program to fit a Simple Linear Regression model to the following sample data:
# X = [1, 2, 3, 4, 5], Y = [2.1, 4.3, 6.1, 7.9, 10.2]. Plot the regression line over the data points.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([2.1, 4.3, 6.1, 7.9, 10.2])

model = LinearRegression()
model.fit(X, Y)
y_pred = model.predict(X)

plt.scatter(X, Y, color='blue')
plt.plot(X, y_pred, color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Linear Regression')
plt.show()

print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
# Out:
# Coefficients: [1.98]
# Intercept: 0.17999999999999794

# %% [markdown]
# Question 7: Fit a Multiple Linear Regression model on this sample data:
# Area = [1200, 1500, 1800, 2000], Rooms = [2, 3, 3, 4], Price = [250000, 300000, 320000, 370000]. Check for multicollinearity using VIF and report the results.

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

data = pd.DataFrame({
    'Area': [1200, 1500, 1800, 2000],
    'Rooms': [2, 3, 3, 4],
    'Price': [250000, 300000, 320000, 370000]
})

X = data[['Area', 'Rooms']]
y = data['Price']

X_const = sm.add_constant(X)
model = sm.OLS(y, X_const).fit()

vif_data = pd.DataFrame()
vif_data['feature'] = X_const.columns
vif_data['VIF'] = [variance_inflation_factor(X_const.values, i) for i in range(X_const.shape[1])]

print(model.summary())
print(vif_data)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     351.0
# Date:                Thu, 04 Sep 2025   Prob (F-statistic):             0.0377
# Time:                        08:48:07   Log-Likelihood:                -35.242
# No. Observations:                   4   AIC:                             76.48
# Df Residuals:                       1   BIC:                             74.64
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.032e+05   9488.293     10.872      0.058   -1.74e+04    2.24e+05
# ...

# %% [markdown]
# Question 8: Implement polynomial regression on the following data:
# X = [1, 2, 3, 4, 5], Y = [2.2, 4.8, 7.5, 11.2, 14.7]. Fit a 2nd-degree polynomial and plot the resulting curve.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([2.2, 4.8, 7.5, 11.2, 14.7])

poly_model = make_pipeline(PolynomialFeatures(2), LinearRegression())
poly_model.fit(X, Y)
y_pred = poly_model.predict(X)

plt.scatter(X, Y, color='blue')
plt.plot(X, y_pred, color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Regression (Degree 2)')
plt.show()

# %% [markdown]
# Question 9: Create a residuals plot for a regression model trained on this data:
# X = [10, 20, 30, 40, 50], Y = [15, 35, 40, 50, 65]. Assess heteroscedasticity by examining the spread of residuals.

# %%
X = np.array([10, 20, 30, 40, 50]).reshape(-1, 1)
Y = np.array([15, 35, 40, 50, 65])

model = LinearRegression()
model.fit(X, Y)
y_pred = model.predict(X)

residuals = Y - y_pred

plt.scatter(X, residuals, color='purple')
plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel('X')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

print('Residuals:', residuals)
# Out:
# Residuals: [-3.   5.5 -1.  -2.5  1. ]

# %% [markdown]
# Question 10: Imagine you are a data scientist working for a real estate company. You need to predict house prices using features like area, number of rooms, and location. However, you detect heteroscedasticity and multicollinearity in your regression model. Explain the steps you would take to address these issues and ensure a robust model.

# %%
print('To address heteroscedasticity: use transformations (log, sqrt), weighted least squares, or robust regression. To handle multicollinearity: remove highly correlated variables, use PCA, or apply regularization techniques like Ridge/Lasso regression.')
# Out:
# To address heteroscedasticity: use transformations (log, sqrt), weighted least squares, or robust regression. To handle multicollinearity: remove highly correlated variables, use PCA, or apply regularization techniques like Ridge/Lasso regression.
